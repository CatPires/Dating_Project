# %%
## csv analysis

# %%
import pandas as pd

# %%
data = pd.read_csv('survey_results.csv')  ## import csv file with the survey results
data.head()
# Out:
#    Age  Gender Sexual orientation       School        Religion  \
# 0   28    Male       Heterosexual     Bachelor         Atheist
# 1   31    Male       Heterosexual  High school       Christian
# 2   27  Female       Heterosexual       Master       Christian
# 3   28    Male       Heterosexual       Master         Atheist
# 4   27    Male       Heterosexual     Bachelor  Pastafarianism
#
#               Income  Personal[Sincerity]  Personal[Loyalty]  \
# 0  1600 - 2000 euros                    6                  7
# 1  1000 - 1300 euros                    7                  7
# 2  1000 - 1300 euros                    6                  8
# 3  1600 - 2000 euros                    8                  8
# 4   800 - 1000 euros                    6                  7
#
#    Personal[Self-confidence]  Personal[Braveness]  ...  Relationship type  ID  \
# 0                          4                    5  ...         Monogamous   0
# ...

# %%
data.iloc[:,:6].describe()  ## check data distribution
# Out:
#              Age
# count  50.000000
# mean   28.140000
# std     8.293125
# min    18.000000
# 25%    23.000000
# 50%    27.000000
# 75%    29.750000
# max    55.000000

# %%
data.iloc[:,6:22].describe()  ## check data distribution
# Out:
#        Personal[Sincerity]  Personal[Loyalty]  Personal[Self-confidence]  \
# count            50.000000          50.000000                  50.000000
# mean              6.560000           7.180000                   5.000000
# std               1.372619           1.466497                   1.603567
# min               2.000000           1.000000                   0.000000
# 25%               6.000000           7.000000                   4.000000
# 50%               7.000000           8.000000                   5.000000
# 75%               7.000000           8.000000                   6.000000
# max               8.000000           8.000000                   8.000000
#
#        Personal[Braveness]  Personal[Optimism]  Personal[Money]  \
# count            50.000000           50.000000         50.00000
# mean              5.320000            5.720000          4.06000
# std               1.448997            1.818723          1.81164
# ...

# %%
data.iloc[:,22:37].describe()  ## check data distribution
# Out:
#        Future Partner[Sincerity]  Future Partner[Loyalty]  \
# count                  15.000000                15.000000
# mean                    7.266667                 7.266667
# std                     1.533747                 1.579632
# min                     2.000000                 2.000000
# 25%                     7.000000                 7.000000
# 50%                     8.000000                 8.000000
# 75%                     8.000000                 8.000000
# max                     8.000000                 8.000000
#
#        Future Partner[Self-confidence]  Future Partner[Braveness]  \
# count                        15.000000                  15.000000
# mean                          5.666667                   5.800000
# std                           1.632993                   1.567528
# min                           1.000000                   1.000000
# 25%                           5.000000                   5.500000
# ...

# %%
data.iloc[:,37:52].describe()  ## check data distribution
# Out:
#        Opposite sex[Sincerity]  Opposite sex[Loyalty]  \
# count                15.000000              15.000000
# mean                  6.866667               7.133333
# std                   1.884776               1.597617
# min                   2.000000               2.000000
# 25%                   7.000000               7.000000
# 50%                   8.000000               8.000000
# 75%                   8.000000               8.000000
# max                   8.000000               8.000000
#
#        Opposite sex[Self-confidence]  Opposite sex[Braveness]  \
# count                      15.000000                15.000000
# mean                        6.466667                 5.933333
# std                         1.641718                 1.533747
# min                         2.000000                 2.000000
# 25%                         6.000000                 5.500000
# 50%                         7.000000                 6.000000
# ...

# %%
data.iloc[:,52:53].describe()  ## check data distribution
# Out:
#        Relationship rate
# count          35.000000
# mean            5.485714
# std             0.658493
# min             4.000000
# 25%             5.000000
# 50%             6.000000
# 75%             6.000000
# max             6.000000

# %%
data.iloc[:,53:70].describe()  ## check data distribution
# Out:
#        Partner[Sincerity]  Partner[Loyalty]  Partner[Self-confidence]  \
# count           35.000000         35.000000                  35.00000
# mean             7.114286          7.400000                   5.60000
# std              1.207122          1.062738                   1.63059
# min              3.000000          3.000000                   2.00000
# 25%              7.000000          7.000000                   4.00000
# 50%              7.000000          8.000000                   6.00000
# 75%              8.000000          8.000000                   7.00000
# max              8.000000          8.000000                   8.00000
#
#        Partner[Braveness]  Partner[Optimism]  Partner[Money]  \
# count           35.000000          35.000000       35.000000
# mean             6.142857           5.485714        4.742857
# std              1.555689           2.105615        1.960535
# min              2.000000           1.000000        0.000000
# ...

# %%
data.iloc[:,70:85].describe()  ## check data distribution
# Out:
#        Partner values[Sincerity]  Partner values[Loyalty]  \
# count                  35.000000                35.000000
# mean                    7.514286                 7.600000
# std                     0.981338                 0.945578
# min                     3.000000                 3.000000
# 25%                     7.000000                 7.500000
# 50%                     8.000000                 8.000000
# 75%                     8.000000                 8.000000
# max                     8.000000                 8.000000
#
#        Partner values[Self-confidence]  Partner values[Braveness]  \
# count                        35.000000                  35.000000
# mean                          6.000000                   5.942857
# std                           1.782266                   1.493965
# min                           0.000000                   2.000000
# 25%                           5.000000                   5.000000
# ...

# %%
data.iloc[:,85:101].describe()  ## check data distribution
# Out:
#        Relationship[Respect]  Relationship[Vulnerability]  \
# count              35.000000                    35.000000
# mean                5.685714                     5.371429
# std                 0.582663                     0.770245
# min                 4.000000                     4.000000
# 25%                 5.500000                     5.000000
# 50%                 6.000000                     6.000000
# 75%                 6.000000                     6.000000
# max                 6.000000                     6.000000
#
#        Relationship[Trust]  Relationship[Honesty]  Relationship[Kindness]  \
# count            35.000000              35.000000               35.000000
# mean              5.571429               5.228571                4.914286
# std               0.739066               0.770245                0.981338
# min               3.000000               4.000000                3.000000
# ...

# %%
data.iloc[:,101:111].describe()  ## check data distribution
# Out:
#              ID  Relationship score  Gender_nm  Sexual orientation_nm  \
# count  50.00000           35.000000  50.000000              49.000000
# mean   24.50000           82.028571   0.460000               0.020408
# std    14.57738            7.636929   0.503457               0.142857
# min     0.00000           59.000000   0.000000               0.000000
# 25%    12.25000           78.000000   0.000000               0.000000
# 50%    24.50000           83.000000   0.000000               0.000000
# 75%    36.75000           88.500000   1.000000               0.000000
# max    49.00000           90.000000   1.000000               1.000000
#
#        School_nm  Income_nm  Relationship_nm   Kids_nm  Religion_nm
# count  50.000000  50.000000         50.00000  50.00000    50.000000
# mean    1.480000   2.280000          0.70000   0.14000     0.300000
# std     0.788696   1.863067          0.46291   0.35051     0.839096
# ...

# %%
list(data.columns)
# Out:
# ['Age',
#  'Gender',
#  'Sexual orientation',
#  'School',
#  'Religion',
#  'Income',
#  'Personal[Sincerity]',
#  'Personal[Loyalty]',
#  'Personal[Self-confidence]',
#  'Personal[Braveness]',
#  'Personal[Optimism]',
#  'Personal[Money]',
#  'Personal[Attractiveness]',
#  'Personal[Intelligence]',
#  'Personal[Charisma]',
#  'Personal[Spirituality]',
#  'Personal[Generosity]',
#  'Personal[Kindness]',
#  'Personal[Adventurous]',
#  'Personal[Fun]',
#  'Personal[Energetic]',
#  'Relationship',
#  'Future Partner[Sincerity]',
#  'Future Partner[Loyalty]',
#  'Future Partner[Self-confidence]',
#  'Future Partner[Braveness]',
#  'Future Partner[Optimism]',
#  'Future Partner[Money]',
#  'Future Partner[Attractiveness]',
#  'Future Partner[Intelligence]',
#  'Future Partner[Charisma]',
#  'Future Partner[Spirituality]',
#  'Future Partner[Generosity]',
#  'Future Partner[Kindness]',
#  'Future Partner[Adventurous]',
#  'Future Partner[Fun]',
#  'Future Partner[Energetic]',
# ...

# %% [markdown]
# ## Lets check how our perception of ourself changes throw age

# %%
from heatmap import heatmap, corrplot

# %%
df_me = data[['Age','Gender_nm','School_nm','Religion_nm','Income_nm','Personal[Sincerity]','Personal[Loyalty]','Personal[Self-confidence]','Personal[Braveness]','Personal[Optimism]','Personal[Money]','Personal[Attractiveness]','Personal[Intelligence]','Personal[Charisma]','Personal[Spirituality]','Personal[Generosity]','Personal[Kindness]','Personal[Adventurous]','Personal[Fun]','Personal[Energetic]','Relationship_nm','Relationship rate','Time together','Kids_nm']]

# %%
corrplot(df_me.corr(), size_scale=100, marker='s')  ## use in dataframe

# %%
df_fut = data[['Age','Gender_nm','School_nm','Religion_nm','Income_nm','Relationship_nm','Relationship rate','Time together','Kids_nm','Future Partner[Sincerity]','Future Partner[Loyalty]','Future Partner[Self-confidence]','Future Partner[Braveness]','Future Partner[Optimism]', 'Future Partner[Money]','Future Partner[Attractiveness]','Future Partner[Intelligence]','Future Partner[Charisma]','Future Partner[Spirituality]', 'Future Partner[Generosity]','Future Partner[Kindness]','Future Partner[Adventurous]','Future Partner[Fun]','Future Partner[Energetic]',]]

# %%
corrplot(df_fut.corr(), size_scale=100, marker='s')  ## use in dataframe

# %%
df_op = data[['Age','Gender_nm','Sexual orientation_nm','School_nm','Religion_nm','Income_nm','Relationship_nm','Relationship rate','Time together','Kids_nm','Opposite sex[Sincerity]','Opposite sex[Loyalty]','Opposite sex[Self-confidence]','Opposite sex[Braveness]','Opposite sex[Optimism]','Opposite sex[Money]','Opposite sex[Attractiveness]','Opposite sex[Intelligence]','Opposite sex[Charisma]','Opposite sex[Spirituality]','Opposite sex[Generosity]', 'Opposite sex[Kindness]','Opposite sex[Adventurous]','Opposite sex[Fun]','Opposite sex[Energetic]']]

# %%
corrplot(df_op.corr(), size_scale=100, marker='s')  ## use in dataframe

# %%
df_part = data[['Age','Gender_nm','Sexual orientation_nm','School_nm','Religion_nm','Income_nm','Relationship_nm','Relationship rate','Time together','Kids_nm','Partner[Sincerity]','Partner[Loyalty]','Partner[Self-confidence]','Partner[Braveness]','Partner[Optimism]','Partner[Money]','Partner[Attractiveness]','Partner[Intelligence]','Partner[Charisma]','Partner[Spirituality]','Partner[Generosity]','Partner[Kindness]','Partner[Adventurous]','Partner[Fun]','Partner[Energetic]']]

# %%
corrplot(df_part.corr(), size_scale=100, marker='s')  ## use in dataframe

# %%
df_pval = data[['Age','Gender_nm','Sexual orientation_nm','School_nm','Religion_nm','Income_nm','Relationship_nm','Relationship rate','Time together','Kids_nm','Partner values[Sincerity]','Partner values[Loyalty]','Partner values[Self-confidence]','Partner values[Braveness]','Partner values[Optimism]','Partner values[Money]','Partner values[Attractiveness]','Partner values[Intelligence]','Partner values[Charisma]','Partner values[Spirituality]','Partner values[Generosity]','Partner values[Kindness]','Partner values[Adventurous]','Partner values[Fun]','Partner values[Energetic]']]

# %%
corrplot(df_pval.corr(), size_scale=100, marker='s')  ## use in dataframe

# %%
df_rel = data[['Age','Gender_nm','Sexual orientation_nm','School_nm','Religion_nm','Income_nm','Relationship_nm','Relationship rate','Time together','Kids_nm','Relationship type','Relationship[Respect]','Relationship[Vulnerability]','Relationship[Trust]','Relationship[Honesty]','Relationship[Kindness]','Relationship[Boundaries]','Relationship[Commitment]','Relationship[Thoughtfulness]','Relationship[Forgiveness]','Relationship[Gentleness]','Relationship[Affection]','Relationship[Appreciation]','Relationship[Validation]','Relationship[Freedom]','Relationship[Alone]']]

# %%
corrplot(df_rel.corr(), size_scale=100, marker='s')  ## use in dataframe

# %%
###### AQUIIIIII ####################

# %%
df_single = data[data['Relationship'] == 'Não']
df_single = df_single[['Timestamp','Age','Gender','Sexual orientation','School','Religion','Income','Personal[Sincerity]','Personal[Loyalty]','Personal[Self-confidence]','Personal[Braveness]','Personal[Optimism]','Personal[Money]','Personal[Attractiveness]','Personal[Intelligence]','Personal[Charisma]','Personal[Spirituality]','Personal[Generosity]','Personal[Kindness]','Personal[Adventurous]','Personal[Fun]','Personal[Energetic]','Relationship','Future Partner[Sincerity]','Future Partner[Loyalty]','Future Partner[Self-confidence]','Future Partner[Braveness]','Future Partner[Optimism]','Future Partner[Money]','Future Partner[Attractiveness]','Future Partner[Intelligence]','Future Partner[Charisma]','Future Partner[Spirituality]','Future Partner[Generosity]','Future Partner[Kindness]','Future Partner[Adventurous]','Future Partner[Fun]','Future Partner[Energetic]','Opposite sex[Sincerity]','Opposite sex[Loyalty]','Opposite sex[Self-confidence]','Opposite sex[Braveness]','Opposite sex[Optimism]','Opposite sex[Money]','Opposite sex[Attractiveness]','Opposite sex[Intelligence]','Opposite sex[Charisma]','Opposite sex[Spirituality]','Opposite sex[Generosity]','Opposite sex[Kindness]','Opposite sex[Adventurous]','Opposite sex[Fun]','Opposite sex[Energetic]']]
df_single.describe()
# Out:
#        Personal[Sincerity]  Personal[Loyalty]  Personal[Self-confidence]  \
# count            15.000000          15.000000                  15.000000
# mean              6.733333           7.200000                   4.800000
# std               1.486447           1.820518                   1.612452
# min               2.000000           1.000000                   1.000000
# 25%               6.500000           7.000000                   4.000000
# 50%               7.000000           8.000000                   5.000000
# 75%               7.500000           8.000000                   6.000000
# max               8.000000           8.000000                   7.000000
#
#        Personal[Braveness]  Personal[Optimism]  Personal[Money]  \
# count            15.000000           15.000000        15.000000
# mean              5.133333            5.266667         3.600000
# std               1.597617            2.086236         1.764734
# ...

# %%
df_couple = data[data['Relationship'] == 'Sim']
df_couple = df_couple[['Timestamp','Age','Gender','Sexual orientation','School','Religion','Income','Personal[Sincerity]','Personal[Loyalty]','Personal[Self-confidence]','Personal[Braveness]','Personal[Optimism]','Personal[Money]','Personal[Attractiveness]','Personal[Intelligence]','Personal[Charisma]','Personal[Spirituality]','Personal[Generosity]','Personal[Kindness]','Personal[Adventurous]','Personal[Fun]','Personal[Energetic]','Relationship','Relationship rate','Time together','Kids','Partner[Sincerity]','Partner[Loyalty]','Partner[Self-confidence]','Partner[Braveness]','Partner[Optimism]','Partner[Money]','Partner[Attractiveness]','Partner[Intelligence]', 'Partner[Charisma]','Partner[Spirituality]','Partner[Generosity]','Partner[Kindness]','Partner[Adventurous]','Partner[Fun]','Partner[Energetic]', 'Partner values[Sincerity]','Partner values[Loyalty]','Partner values[Self-confidence]','Partner values[Braveness]','Partner values[Optimism]','Partner values[Money]','Partner values[Attractiveness]','Partner values[Intelligence]','Partner values[Charisma]','Partner values[Spirituality]','Partner values[Generosity]','Partner values[Kindness]','Partner values[Adventurous]','Partner values[Fun]','Partner values[Energetic]','Relationship[Respect]','Relationship[Vulnerability]','Relationship[Trust]','Relationship[Honesty]','Relationship[Kindness]','Relationship[Boundaries]','Relationship[Commitment]','Relationship[Thoughtfulness]','Relationship[Forgiveness]','Relationship[Gentleness]','Relationship[Affection]','Relationship[Appreciation]','Relationship[Validation]','Relationship[Freedom]','Relationship[Alone]','Relationship type']]
df_couple.describe()
# Out:
#        Personal[Sincerity]  Personal[Loyalty]  Personal[Self-confidence]  \
# count            35.000000          35.000000                  35.000000
# mean              6.485714           7.171429                   5.085714
# std               1.336621           1.316987                   1.615575
# min               2.000000           2.000000                   0.000000
# 25%               6.000000           7.000000                   4.000000
# 50%               7.000000           7.000000                   5.000000
# 75%               7.000000           8.000000                   6.000000
# max               8.000000           8.000000                   8.000000
#
#        Personal[Braveness]  Personal[Optimism]  Personal[Money]  \
# count            35.000000           35.000000        35.000000
# mean              5.400000            5.914286         4.257143
# std               1.397477            1.686825         1.820518
# ...

# %%
test1 = df_couple[['Personal[Sincerity]','Personal[Loyalty]','Personal[Self-confidence]','Personal[Braveness]','Personal[Optimism]','Personal[Money]','Personal[Attractiveness]','Personal[Intelligence]','Personal[Charisma]','Personal[Spirituality]','Personal[Generosity]','Personal[Kindness]','Personal[Adventurous]','Personal[Fun]','Personal[Energetic]','Partner values[Sincerity]','Partner values[Loyalty]','Partner values[Self-confidence]','Partner values[Braveness]','Partner values[Optimism]','Partner values[Money]','Partner values[Attractiveness]','Partner values[Intelligence]','Partner values[Charisma]','Partner values[Spirituality]','Partner values[Generosity]','Partner values[Kindness]','Partner values[Adventurous]','Partner values[Fun]','Partner values[Energetic]']]

corrplot(test1.corr(), size_scale=10, marker='s')  ## use in dataframe
